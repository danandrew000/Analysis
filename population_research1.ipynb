# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file = pd.read_excel('C:/Users/Andrew/research/estimated_population.xlsx')

# %%
file[6:34]
# Out:
#    1. ЧИСЛЕННОСТЬ И СОСТАВ НАСЕЛЕНИЯ                             Unnamed: 1  \
# 6                               Годы                         На начало года
# 7                                NaN  все                         население
# 8                                NaN                                    NaN
# 9                                NaN                                    NaN
# 10                               NaN                                    NaN
# 11                              2024                               146079.7
# 12                              2025                               145631.8
# 13                              2026                               145159.3
# 14                              2027                               144672.2
# 15                              2028                               144181.3
# 16                              2029                               143709.1
# 17                              2030                               143255.2
# 18                              2031                               142815.3
# 19                              2032                               142391.5
# 20                              2033                               141989.2
# 21                              2034                               141621.3
# 22                              2035                               141279.3
# 23                              2036                                 140963
# 24                              2037                               140672.4
# 25                              2038                               140413.2
# 26                              2039                               140173.2
# 27                              2040                               139945.2
# 28                              2041                               139726.7
# 29                              2042                               139520.5
# 30                              2043                               139325.6
# 31                              2044                               139135.9
# 32                              2045                               138951.9
# 33                              2046                               138771.3
#
#       Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 6            NaN        NaN          NaN       Годы
# 7   в том числе:        NaN  доля город-        NaN
# 8      городское   сельское  ского насе-        NaN
# 9            NaN        NaN    ления (%)        NaN
# 10           NaN        NaN          NaN        NaN
# 11      109485.5    36594.2         74.9       2024
# 12        109267    36364.8           75       2025
# 13        109024    36135.3         75.1       2026
# 14      108764.6    35907.6         75.2       2027
# 15      108497.5    35683.8         75.3       2028
# 16      108239.8    35469.3         75.3       2029
# 17      107991.4    35263.8         75.4       2030
# 18      107749.5    35065.8         75.4       2031
# 19      107516.3    34875.2         75.5       2032
# 20      107296.9    34692.3         75.6       2033
# 21      107101.8    34519.5         75.6       2034
# 22      106925.4    34353.9         75.7       2035
# 23      106768.5    34194.5         75.7       2036
# 24      106631.9    34040.5         75.8       2037
# 25      106520.5    33892.7         75.9       2038
# 26      106425.6    33747.6         75.9       2039
# 27      106341.5    33603.7           76       2040
# 28      106265.7      33461         76.1       2041
# 29      106201.3    33319.2         76.1       2042
# 30      106146.4    33179.2         76.2       2043
# 31      106095.7    33040.2         76.3       2044
# 32      106048.7    32903.2         76.3       2045
# 33      106003.8    32767.5         76.4        NaN
#
#                                  Unnamed: 6    Unnamed: 7 Unnamed: 8  \
# 6                          В среднем за год           NaN        NaN
# 7   все                           население  в том числе:        NaN
# 8                                       NaN     городское   сельское
# 9                                       NaN           NaN        NaN
# 10                                      NaN           NaN        NaN
# 11                                 145855.8      109376.2    36479.6
# 12                                 145395.6      109145.5    36250.1
# 13                                 144915.8      108894.3    36021.5
# 14                                 144426.8      108631.1    35795.7
# 15                                 143945.2      108368.7    35576.5
# 16                                 143482.2      108115.6    35366.6
# 17                                 143035.2      107870.5    35164.7
# 18                                 142603.4      107632.9    34970.5
# 19                                 142190.4      107406.6    34783.8
# 20                                 141805.3      107199.3      34606
# 21                                 141450.3      107013.6    34436.7
# 22                                 141121.1        106847    34274.1
# 23                                 140817.7      106700.2    34117.5
# 24                                 140542.8      106576.2    33966.6
# 25                                 140293.2      106473.1    33820.1
# 26                                 140059.2      106383.6    33675.6
# 27                                   139836      106303.6    33532.4
# 28                                 139623.6      106233.5    33390.1
# 29                                 139423.1      106173.8    33249.3
# 30                                 139230.8        106121    33109.8
# 31                                 139043.9      106072.2    32971.7
# 32                                 138861.6      106026.3    32835.3
# 33                                      NaN           NaN        NaN
#
#     Unnamed: 9  Содержание
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN
# 30         NaN         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN

# %%
ffile = file[6:34]

# %%
file1 = ffile.iloc[5:34, 0:5]

# %%
b_of_year = file1.rename(columns={'Годы':'Years','Все население': 'All population', 'Городское' : 'Urban', 'Сельское': 'Rural', 'Доля городского населения': 'Share of urban population'})

# %%
b_of_year
# Out:
#    Years All population     Urban    Rural Share of urban population
# 11  2024       146079.7  109485.5  36594.2                      74.9
# 12  2025       145631.8    109267  36364.8                        75
# 13  2026       145159.3    109024  36135.3                      75.1
# 14  2027       144672.2  108764.6  35907.6                      75.2
# 15  2028       144181.3  108497.5  35683.8                      75.3
# 16  2029       143709.1  108239.8  35469.3                      75.3
# 17  2030       143255.2  107991.4  35263.8                      75.4
# 18  2031       142815.3  107749.5  35065.8                      75.4
# 19  2032       142391.5  107516.3  34875.2                      75.5
# 20  2033       141989.2  107296.9  34692.3                      75.6
# 21  2034       141621.3  107101.8  34519.5                      75.6
# 22  2035       141279.3  106925.4  34353.9                      75.7
# 23  2036         140963  106768.5  34194.5                      75.7
# 24  2037       140672.4  106631.9  34040.5                      75.8
# 25  2038       140413.2  106520.5  33892.7                      75.9
# 26  2039       140173.2  106425.6  33747.6                      75.9
# 27  2040       139945.2  106341.5  33603.7                        76
# 28  2041       139726.7  106265.7    33461                      76.1
# 29  2042       139520.5  106201.3  33319.2                      76.1
# 30  2043       139325.6  106146.4  33179.2                      76.2
# 31  2044       139135.9  106095.7  33040.2                      76.3
# 32  2045       138951.9  106048.7  32903.2                      76.3
# 33  2046       138771.3  106003.8  32767.5                      76.4

# %%
file2 = ffile.iloc[5:30, 5:9]

# %%
file2 = file2[0:22]

# %%
m_of_year = file2.rename(columns={'Годы': 'Years', 'Все население' : 'All population', 'Городское': 'Urban', 'Сельское': 'Rural'})

# %%
m_of_year
# Out:
#    Years All population     Urban    Rural
# 11  2024       145855.8  109376.2  36479.6
# 12  2025       145395.6  109145.5  36250.1
# 13  2026       144915.8  108894.3  36021.5
# 14  2027       144426.8  108631.1  35795.7
# 15  2028       143945.2  108368.7  35576.5
# 16  2029       143482.2  108115.6  35366.6
# 17  2030       143035.2  107870.5  35164.7
# 18  2031       142603.4  107632.9  34970.5
# 19  2032       142190.4  107406.6  34783.8
# 20  2033       141805.3  107199.3    34606
# 21  2034       141450.3  107013.6  34436.7
# 22  2035       141121.1    106847  34274.1
# 23  2036       140817.7  106700.2  34117.5
# 24  2037       140542.8  106576.2  33966.6
# 25  2038       140293.2  106473.1  33820.1
# 26  2039       140059.2  106383.6  33675.6
# 27  2040         139836  106303.6  33532.4
# 28  2041       139623.6  106233.5  33390.1
# 29  2042       139423.1  106173.8  33249.3
# 30  2043       139230.8    106121  33109.8
# 31  2044       139043.9  106072.2  32971.7
# 32  2045       138861.6  106026.3  32835.3

# %%
b_of_year['All population'].plot.line(color = 'blue')
# Out:
# <Axes: >

# %%
m_of_year['All population'].plot.line(color = 'green')
# Out:
# <Axes: >

# %%
plt.plot(b_of_year['All population'], b_of_year['Years'], color = 'blue')
plt.plot(m_of_year['All population'], m_of_year['Years'], color = 'green')
plt.xlabel('All population')
plt.ylabel('Years')
plt.show()
